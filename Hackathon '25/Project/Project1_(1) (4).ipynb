# %% [markdown]
# ### **PREDICTIVE MODELING OF DIARRHEAL DISEASE BASED ON DRINKING WATER QUALITY PARAMETERS**

# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#from google.colab import files
#files.upload()

# %%
water_data = pd.read_csv('water_quality_prediction.csv')
water_data
# Out:
#        Index        pH          Iron   Nitrate    Chloride           Lead  \
# 0          0  8.332988  8.350000e-05  8.605777  122.799772   3.710000e-52
# 1          1  6.917863  8.050000e-05  3.734167  227.029851   7.850000e-94
# 2          2  5.443762  2.010586e-02  3.816994  230.995630   5.290000e-76
# 3          3  7.955339  1.439878e-01  8.224944  178.129940  4.000000e-176
# 4          4  8.091909  2.167128e-03  9.925788  186.540872  4.170000e-132
# ...      ...       ...           ...       ...         ...            ...
# 13485  13485  8.295523  3.940000e-09  8.655295   91.541804   1.351378e-03
# 13486  13486  7.161280  1.650000e-07  3.408242  203.256967   7.160000e-60
# 13487  13487  8.435621  2.763102e-02  3.911660   94.823359   6.590000e-31
# 13488  13488  7.111199  1.440000e-05  4.780785  121.394190   1.150000e-07
# 13489  13489  6.675299  2.685808e-01  4.176910  206.850959   2.080000e-32
#
#            Zinc           Color  Turbidity  Fluoride  ...  Chlorine  \
# 0      3.434827       Colorless   0.022683  0.607283  ...  3.708178
# 1      1.245317    Faint Yellow   0.019007  0.622874  ...  3.292038
# 2      0.528280    Light Yellow   0.319956  0.423423  ...  3.560224
# 3      4.027879  Near Colorless   0.166319  0.208454  ...  3.516907
# 4      3.807511    Light Yellow   0.004867  0.222912  ...  3.177849
# ...         ...             ...        ...       ...  ...       ...
# 13485  0.182157  Near Colorless   0.204289  0.113311  ...  2.745167
# 13486  0.224360    Faint Yellow   0.430254  0.201591  ...  2.553949
# 13487  0.510364       Colorless   0.061130  1.599388  ...  3.141153
# 13488  0.236547  Near Colorless   0.024841  0.923704  ...  3.803457
# 13489  0.191125  Near Colorless   0.182383  0.156001  ...  2.543702
#
#           Manganese  Total Dissolved Solids   Source  Water Temperature  \
# 0      2.270000e-15              332.118789      NaN                NaN
# 1      8.020000e-07              284.641984     Lake          15.348981
# 2      7.007989e-02              570.054094    River          11.643467
# 3      2.468295e-02              100.043838   Ground          10.092392
# 4      3.296139e-03              168.075545   Spring          15.249416
# ...             ...                     ...      ...                ...
# 13485  1.248190e-03              411.483691  Aquifer          15.486861
# 13486  2.403928e-03              488.537426   Spring          15.633130
# 13487  4.410000e-15              278.793867  Aquifer          30.974614
# 13488  2.270000e-06              417.990028     Lake          36.517741
# 13489  7.810000e-05              421.942688  Aquifer          26.916662
#
#        Air Temperature     Month   Day  Time of Day  Target
# 0            43.493324   January  29.0          4.0     0.0
# 1            71.220586  November  26.0         16.0     0.0
# 2            44.891330   January  31.0          8.0     0.0
# 3            60.843233     April   1.0         21.0     0.0
# 4            69.336671      June  29.0          7.0     0.0
# ...                ...       ...   ...          ...     ...
# 13485        67.414595     April  22.0          9.0     0.0
# 13486        67.383781       May  22.0         16.0     0.0
# 13487        76.152382  December  18.0         16.0     0.0
# 13488        90.588109   October  30.0         17.0     0.0
# 13489        55.100000       NaN   NaN          NaN     NaN
#
# [13490 rows x 24 columns]

# %%
water_data.head() #displays the first 5 data's
# Out:
#    Index        pH      Iron   Nitrate    Chloride           Lead      Zinc  \
# 0      0  8.332988  0.000083  8.605777  122.799772   3.710000e-52  3.434827
# 1      1  6.917863  0.000081  3.734167  227.029851   7.850000e-94  1.245317
# 2      2  5.443762  0.020106  3.816994  230.995630   5.290000e-76  0.528280
# 3      3  7.955339  0.143988  8.224944  178.129940  4.000000e-176  4.027879
# 4      4  8.091909  0.002167  9.925788  186.540872  4.170000e-132  3.807511
#
#             Color  Turbidity  Fluoride  ...  Chlorine     Manganese  \
# 0       Colorless   0.022683  0.607283  ...  3.708178  2.270000e-15
# 1    Faint Yellow   0.019007  0.622874  ...  3.292038  8.020000e-07
# 2    Light Yellow   0.319956  0.423423  ...  3.560224  7.007989e-02
# 3  Near Colorless   0.166319  0.208454  ...  3.516907  2.468295e-02
# 4    Light Yellow   0.004867  0.222912  ...  3.177849  3.296139e-03
#
#    Total Dissolved Solids  Source  Water Temperature  Air Temperature  \
# 0              332.118789     NaN                NaN        43.493324
# 1              284.641984    Lake          15.348981        71.220586
# 2              570.054094   River          11.643467        44.891330
# 3              100.043838  Ground          10.092392        60.843233
# 4              168.075545  Spring          15.249416        69.336671
#
#       Month   Day  Time of Day  Target
# 0   January  29.0          4.0     0.0
# 1  November  26.0         16.0     0.0
# 2   January  31.0          8.0     0.0
# 3     April   1.0         21.0     0.0
# 4      June  29.0          7.0     0.0
#
# [5 rows x 24 columns]

# %%
water_data.tail() #displays the last 5 data's
# Out:
#        Index        pH          Iron   Nitrate    Chloride          Lead  \
# 13485  13485  8.295523  3.940000e-09  8.655295   91.541804  1.351378e-03
# 13486  13486  7.161280  1.650000e-07  3.408242  203.256967  7.160000e-60
# 13487  13487  8.435621  2.763102e-02  3.911660   94.823359  6.590000e-31
# 13488  13488  7.111199  1.440000e-05  4.780785  121.394190  1.150000e-07
# 13489  13489  6.675299  2.685808e-01  4.176910  206.850959  2.080000e-32
#
#            Zinc           Color  Turbidity  Fluoride  ...  Chlorine  \
# 13485  0.182157  Near Colorless   0.204289  0.113311  ...  2.745167
# 13486  0.224360    Faint Yellow   0.430254  0.201591  ...  2.553949
# 13487  0.510364       Colorless   0.061130  1.599388  ...  3.141153
# 13488  0.236547  Near Colorless   0.024841  0.923704  ...  3.803457
# 13489  0.191125  Near Colorless   0.182383  0.156001  ...  2.543702
#
#           Manganese  Total Dissolved Solids   Source  Water Temperature  \
# 13485  1.248190e-03              411.483691  Aquifer          15.486861
# 13486  2.403928e-03              488.537426   Spring          15.633130
# 13487  4.410000e-15              278.793867  Aquifer          30.974614
# 13488  2.270000e-06              417.990028     Lake          36.517741
# 13489  7.810000e-05              421.942688  Aquifer          26.916662
#
#        Air Temperature     Month   Day  Time of Day  Target
# 13485        67.414595     April  22.0          9.0     0.0
# 13486        67.383781       May  22.0         16.0     0.0
# 13487        76.152382  December  18.0         16.0     0.0
# 13488        90.588109   October  30.0         17.0     0.0
# 13489        55.100000       NaN   NaN          NaN     NaN
#
# [5 rows x 24 columns]

# %%
water_data.shape #the rows and columns
# Out:
# (13490, 24)

# %%
water_data.info() #features in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490 entries, 0 to 13489
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   13490 non-null  int64
#  1   pH                      13227 non-null  float64
#  2   Iron                    13391 non-null  float64
#  3   Nitrate                 13247 non-null  float64
#  4   Chloride                13114 non-null  float64
#  5   Lead                    13419 non-null  float64
#  6   Zinc                    13150 non-null  float64
#  7   Color                   13472 non-null  object
#  8   Turbidity               13370 non-null  float64
#  9   Fluoride                13023 non-null  float64
#  10  Copper                  13056 non-null  float64
#  11  Odor                    13084 non-null  float64
#  12  Sulfate                 13075 non-null  float64
#  13  Conductivity            13114 non-null  float64
#  14  Chlorine                13355 non-null  float64
#  15  Manganese               13245 non-null  float64
#  16  Total Dissolved Solids  13485 non-null  float64
#  17  Source                  13296 non-null  object
#  18  Water Temperature       13105 non-null  float64
#  19  Air Temperature         13423 non-null  float64
#  20  Month                   13284 non-null  object
#  21  Day                     13271 non-null  float64
#  22  Time of Day             13265 non-null  float64
#  23  Target                  13489 non-null  float64
# dtypes: float64(20), int64(1), object(3)
# memory usage: 2.5+ MB

# %%
water_data.describe() #mean, standard deviation, min
# Out:
#               Index            pH          Iron       Nitrate      Chloride  \
# count  13490.000000  13227.000000  1.339100e+04  13247.000000  13114.000000
# mean    6744.500000      7.463932  7.030559e-02      5.788980    173.436597
# std     3894.371901      0.696417  3.178854e-01      2.655479     54.473915
# min        0.000000      3.123675  4.020000e-36      0.729568     38.977696
# 25%     3372.250000      6.973405  6.545000e-06      3.904171    134.929831
# 50%     6744.500000      7.461944  1.520293e-03      5.449208    170.442429
# 75%    10116.750000      7.958861  3.549807e-02      7.346497    207.895949
# max    13489.000000     11.176598  9.032577e+00     37.853915    732.387659
#
#                 Lead          Zinc     Turbidity      Fluoride        Copper  \
# count   1.341900e+04  13150.000000  1.337000e+04  13023.000000  1.305600e+04
# mean    3.894249e-04      1.457742  3.739627e-01      0.861583  4.277804e-01
# std     1.479799e-02      1.367315  6.272807e-01      0.662777  4.456322e-01
# min     0.000000e+00      0.000028  2.310000e-11      0.000319  4.440000e-08
# 25%    4.350000e-123      0.412515  3.318857e-02      0.364160  1.204257e-01
# 50%     3.830000e-64      1.048384  1.754248e-01      0.727933  3.240113e-01
# 75%     1.125000e-27      2.162775  5.137567e-01      1.233850  6.173356e-01
# max     1.532888e+00     17.468694  1.283193e+01      7.803605  1.000881e+01
#
#        ...       Sulfate  Conductivity      Chlorine     Manganese  \
# count  ...  13075.000000  13114.000000  13355.000000  1.324500e+04
# mean   ...    139.171378    425.138094      3.174017  4.341843e-02
# std    ...     59.066930    188.919161      0.649792  2.932331e-01
# min    ...     16.164578     31.431001      1.224162  2.820000e-36
# 25%    ...     96.482786    288.838517      2.710814  1.120000e-06
# 50%    ...    131.960878    397.603169      3.161399  2.850770e-04
# 75%    ...    175.655143    532.432229      3.617632  7.743089e-03
# max    ...   1279.553774   1662.490270      9.491165  1.184261e+01
#
#        Total Dissolved Solids  Water Temperature  Air Temperature  \
# count            13485.000000       13105.000000     13423.000000
# mean               256.772155          19.069927        60.056511
# std                148.957739          11.101887        17.909892
# min                  0.034175           1.558907        -3.562259
# 25%                128.553513          11.326866        48.010701
# 50%                255.934922          16.508648        60.037640
# 75%                383.938903          23.754799        72.339608
# max                579.579250         115.056432       126.757062
#
#                 Day   Time of Day   Target
# count  13271.000000  13265.000000  13489.0
# mean      15.701982     11.447870      0.0
# std        8.820740      6.938045      0.0
# min        1.000000      0.000000      0.0
# 25%        8.000000      5.000000      0.0
# 50%       16.000000     11.000000      0.0
# 75%       23.000000     18.000000      0.0
# max       31.000000     23.000000      0.0
#
# [8 rows x 21 columns]

# %%
water_data.isnull().sum() # missing values
# Out:
# Index                       0
# pH                        263
# Iron                       99
# Nitrate                   243
# Chloride                  376
# Lead                       71
# Zinc                      340
# Color                      18
# Turbidity                 120
# Fluoride                  467
# Copper                    434
# Odor                      406
# Sulfate                   415
# Conductivity              376
# Chlorine                  135
# Manganese                 245
# Total Dissolved Solids      5
# Source                    194
# Water Temperature         385
# Air Temperature            67
# Month                     206
# Day                       219
# Time of Day               225
# Target                      1
# dtype: int64

# %%
water_data = water_data.dropna() #removing the null values

# %%
water_data.isnull().sum() # after removal of null values
# Out:
# Index                     0
# pH                        0
# Iron                      0
# Nitrate                   0
# Chloride                  0
# Lead                      0
# Zinc                      0
# Color                     0
# Turbidity                 0
# Fluoride                  0
# Copper                    0
# Odor                      0
# Sulfate                   0
# Conductivity              0
# Chlorine                  0
# Manganese                 0
# Total Dissolved Solids    0
# Source                    0
# Water Temperature         0
# Air Temperature           0
# Month                     0
# Day                       0
# Time of Day               0
# Target                    0
# dtype: int64

# %% [markdown]
# ## **Analyzing the Water Quality Parameters**

# %% [markdown]
# # **Chemical Parameters - Nitrate (NO₃⁻), Chlorine residual, Fluoride,  Turbidity, Total Dissolved Solids (TDS)**

# %%
sns.kdeplot(water_data["Nitrate"], shade = True)
# Out:
# <Axes: xlabel='Nitrate', ylabel='Density'>

# %%
# Function to classify nitrate safety
def nitrate_status(value):
    if value <= 50:
        return 'Safe'
    else:
        return 'Unsafe'

# %%
# Add status column
water_data['Nitrate Status'] = water_data['Nitrate'].apply(nitrate_status)

# %%
water_data[['Index', 'Nitrate', 'Nitrate Status']].head()
# Out:
#    Index   Nitrate Nitrate Status
# 1      1  3.734167           Safe
# 2      2  3.816994           Safe
# 4      4  9.925788           Safe
# 7      7  9.261676           Safe
# 9      9  3.620641           Safe

# %%
# Count of status types
print("\n📊 Nitrate Status Counts:")
print(water_data['Nitrate Status'].value_counts())
# Out:
# 📊 Nitrate Status Counts:
# Nitrate Status
# Safe    9046
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Nitrate Status', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='Nitrate Status', ylabel='count'>

# %%
sns.histplot(water_data['Nitrate'], bins=10, kde=True, color='lightgreen')
plt.axvline(50, color='red', linestyle='--', label='WHO Safe Limit (50 mg/L')
plt.title("Nitrate Level Distribution")
plt.legend()
plt.show()

# %% [markdown]
# **Chlorine**

# %%
sns.kdeplot(water_data["Chlorine"], shade = True)
# Out:
# <Axes: xlabel='Chlorine', ylabel='Density'>

# %%
# Function to classify chlorine status
def chlorine_status(value):
    if value < 0.2:
        return 'Low'
    elif 0.2 <= value <= 1.0:
        return 'Safe'
    elif 1.0 < value <= 5.0:
        return 'High'
    else:
        return 'Unsafe'

# %%
sns.countplot(x = 'Color', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='Color', ylabel='count'>

# %%
# Add status column
water_data['Chlorine Status'] = water_data['Chlorine'].apply(chlorine_status)

# %%
# Count and display chlorine status
print("Chlorine Status Counts:")
print(water_data['Chlorine Status'].value_counts())
# Out:
# Chlorine Status Counts:
# Chlorine Status
# High      8964
# Unsafe      82
# Name: count, dtype: int64

# %%
print("Number of unsafe chlorine samples:", (water_data['Chlorine'] >= 5).sum())
# Out:
# Number of unsafe chlorine samples: 13090

# %%
sns.histplot(water_data['Chlorine'], bins=10, kde=True, color='skyblue')
plt.axvline(5, color='red', linestyle='--', label='Unsafe Level (5 mg/L)')
plt.title("Chlorine Level Distribution")
plt.legend()
plt.show()

# %%
sns.countplot(x = 'Chlorine Status', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='Chlorine Status', ylabel='count'>

# %% [markdown]
# **Fluoride**

# %%
sns.kdeplot(water_data["Fluoride"], shade = True)
# Out:
# <Axes: xlabel='Fluoride', ylabel='Density'>

# %%
# Classify fluoride safety levels
water_data['Fluoride Status'] = water_data['Fluoride'].apply(
    lambda x: 'Safe' if x <= 1.0 else
              'Caution' if x <= 1.5 else
              'Unsafe'
)

# %%
water_data[['Index', 'Fluoride', 'Fluoride Status']].head()
# Out:
#    Index  Fluoride Fluoride Status
# 1      1  0.622874            Safe
# 2      2  0.423423            Safe
# 4      4  0.222912            Safe
# 7      7  1.016196         Caution
# 9      9  0.842107            Safe

# %%
# Count of status types
print("\n📊 Fluoride Status Counts:")
print(water_data['Fluoride Status'].value_counts())
# Out:
# 📊 Fluoride Status Counts:
# Fluoride Status
# Safe       5887
# Caution    1748
# Unsafe     1411
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Fluoride Status', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='Fluoride Status', ylabel='count'>

# %%
sns.histplot(water_data['Fluoride'], bins=10, kde=True, color='lightgreen')
plt.axvline(1, color='red', linestyle='--', label='WHO Safe Limit (1')
plt.title("Fluoride Level Distribution")
plt.legend()
plt.show()

# %% [markdown]
# **Turbidity**

# %%
sns.kdeplot(water_data["Turbidity"], shade = True)
# Out:
# <Axes: xlabel='Turbidity', ylabel='Density'>

# %%
# Function to classify turbidity levels
def turbidity_status(ntu):
    if ntu < 1:
        return 'Excellent', 'Recommended for effective disinfection'
    elif 1 <= ntu <= 5:
        return 'Acceptable', 'Safe appearance, but may reduce disinfection'
    else:
        return 'Unacceptable', 'Poor appearance, disinfection may be ineffective'

# %%
# Apply classification
water_data[['Turbidity Status', 'Remarks']] = water_data['Turbidity'].apply(lambda x: pd.Series(turbidity_status(x)))

# %%
# Count of status types
print("\n📊 Turbidity Status Counts:")
print(water_data['Turbidity Status'].value_counts())
# Out:
# 📊 Turbidity Status Counts:
# Turbidity Status
# Excellent       8469
# Acceptable       550
# Unacceptable      27
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Turbidity Status', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='Turbidity Status', ylabel='count'>

# %%
sns.histplot(water_data['Turbidity'], bins=10, kde=True, color='lightgreen')
plt.axvline(5, color='red', linestyle='--', label='WHO Safe Limit (5 NTU')
plt.title("Turbidity Level Distribution")
plt.legend()
plt.show()

# %% [markdown]
# **Total Dissolved Solids**

# %%
water_data[['Turbidity', 'Turbidity Status', 'Remarks']].head()
# Out:
#    Turbidity Turbidity Status                                 Remarks
# 1   0.019007        Excellent  Recommended for effective disinfection
# 2   0.319956        Excellent  Recommended for effective disinfection
# 4   0.004867        Excellent  Recommended for effective disinfection
# 7   0.047803        Excellent  Recommended for effective disinfection
# 9   0.050613        Excellent  Recommended for effective disinfection

# %%
sns.kdeplot(water_data["Total Dissolved Solids"], shade = True)
# Out:
# <Axes: xlabel='Total Dissolved Solids', ylabel='Density'>

# %%
# Function to classify water quality based on TDS
def tds_quality(tds):
    if tds <= 300:
        return 'Excellent', 'Ideal for drinking'
    elif 300 < tds <= 600:
        return 'Good', 'Acceptable taste'
    elif 600 < tds <= 900:
        return 'Fair', 'Slightly salty or mineral taste'
    elif 900 < tds <= 1200:
        return 'Poor', 'Unpleasant taste'
    else:
        return 'Unacceptable', 'Not recommended for drinking'

# %%
# Apply classification
water_data[['Water Quality', 'Remarks']] = water_data['Total Dissolved Solids'].apply(lambda x: pd.Series(tds_quality(x)))

# %%
# Display the classified data
water_data[['Total Dissolved Solids', 'Water Quality', 'Remarks']].head()
# Out:
#    Total Dissolved Solids Water Quality             Remarks
# 1              284.641984     Excellent  Ideal for drinking
# 2              570.054094          Good    Acceptable taste
# 4              168.075545     Excellent  Ideal for drinking
# 7              214.553104     Excellent  Ideal for drinking
# 9              113.909077     Excellent  Ideal for drinking

# %%
# Count of status types
print("\n📊 Total Dissolved Solids Status Counts:")
print(water_data['Water Quality'].value_counts())
# Out:
# 📊 Total Dissolved Solids Status Counts:
# Water Quality
# Excellent    5327
# Good         3719
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Water Quality', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='Water Quality', ylabel='count'>

# %%
sns.histplot(water_data['Total Dissolved Solids'], bins=10, kde=True, color='lightgreen')
plt.axvline(300, color='red', linestyle='--', label='WHO Safe Limit (300 mg/L')
plt.title("TDS Level Distribution")
plt.legend()
plt.show()

# %% [markdown]
# ## **Physical Parameters - pH, Temperature, Color & Odor**

# %% [markdown]
# **pH**

# %%
sns.kdeplot(water_data["pH"], shade = True)
# Out:
# <Axes: xlabel='pH', ylabel='Density'>

# %%
# Function to classify pH status
def pH_status(value):
    if 0.0 < value < 0.69:
        return 'Acidic'
    elif 7.1 <= value <= 14.0:
        return 'Basic'
    else:
        return 'Pure Water'

# %%
# Add status column
water_data['pH Status'] = water_data['pH'].apply(pH_status)

# %%
# Count and display pH status
print("pH Counts:")
print(water_data['pH Status'].value_counts())
# Out:
# pH Counts:
# pH Status
# Basic         6197
# Pure Water    2849
# Name: count, dtype: int64

# %%
sns.countplot(x = 'pH Status', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='pH Status', ylabel='count'>

# %%
print("Number of pure water samples:", (water_data['pH'] == 7).sum())
# Out:
# Number of pure water samples: 0

# %%
sns.histplot(water_data['pH'], bins=10, kde=True, color='skyblue')
plt.axvline(7, color='red', linestyle='--', label='Pure Water Level')
plt.title("pH Level Distribution")
plt.legend()
plt.show()

# %% [markdown]
# **Color**

# %%
sns.countplot(x = 'Color', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='Color', ylabel='count'>

# %% [markdown]
# **Odor**

# %%
sns.countplot(x = 'Odor', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='Odor', ylabel='count'>

# %% [markdown]
# # **Environmental / Supporting Parameters**

# %% [markdown]
# **Source**

# %%
sns.countplot(x = 'Source', data = water_data, palette = 'Set2')
# Out:
# <Axes: xlabel='Source', ylabel='count'>

# %%
# Classify severity
water_data['Severity'] = water_data['Target'].apply(
    lambda x: 'Diahreal Case' if x == 0 else
              'Not Diarrheal Case'
)

# %%
water_data['Remarks'] = water_data['Severity'].apply(
    lambda s: 'Under control' if s == 0 else
                   'Outbreak / Emergency alert'
)

# %%
water_data[['Index', 'Target', 'Remarks']].head(111)
# Out:
#      Index  Target                     Remarks
# 1        1       0  Outbreak / Emergency alert
# 2        2       0  Outbreak / Emergency alert
# 4        4       0  Outbreak / Emergency alert
# 7        7       0  Outbreak / Emergency alert
# 9        9       0  Outbreak / Emergency alert
# ..     ...     ...                         ...
# 157    157       0  Outbreak / Emergency alert
# 159    159       0  Outbreak / Emergency alert
# 160    160       0  Outbreak / Emergency alert
# 161    161       0  Outbreak / Emergency alert
# 164    164       0  Outbreak / Emergency alert
#
# [111 rows x 3 columns]

# %% [markdown]
# **Time Series Forecasting**

# %%
# Convert float time (e.g., 9.5) to HH:MM string
def float_to_time_str(t):
    hour = int(t)
    minute = int((t - hour) * 60)
    return f"{hour:02}:{minute:02}"

# %%
water_data['Formatted Time'] = water_data['Time of Day'].apply(float_to_time_str)

# %%
# Combine into datetime
water_data['Datetime'] = pd.to_datetime(
    water_data['Month'] + ' ' +
    water_data['Day'].astype(str) + ' 2023 ' +
    water_data['Formatted Time']
)

# %%
# Set datetime index and clean up
water_data.set_index('Datetime', inplace=True)
water_data.drop(columns=['Month', 'Day', 'Time of Day', 'Formatted Time'], inplace=True)

# %%
# Plot
plt.figure(figsize=(10, 5))
plt.plot(water_data.index, water_data['Target'], marker='o', linestyle='-', color='darkred')
plt.title('Diarrheal Cases Over Time')
plt.xlabel('Datetime')
plt.ylabel('Number of Cases')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Dropping the Columns**

# %%
water_data.drop(columns=['Iron', 'Chloride', 'Lead', 'Zinc', 'Color', 'Copper', 'Odor', 'Sulfate', 'Conductivity', 'Manganese', 'Source'], inplace=True)

# %%
cols_to_drop = ['Month']
water_data = water_data.drop(columns=[col for col in cols_to_drop if col in water_data.columns])

# %%
cols_to_drop = ['Month', 'Chlorine Status', 'pH Status', 'Nitrate Status', 'Water Quality', 'Fluoride Status', 'Remarks', 'Turbidity Status', 'Severity']
water_data = water_data.drop(columns=[col for col in cols_to_drop if col in water_data.columns])

# %%
X = water_data.drop(columns = 'Target', axis = 1)
Y = water_data['Target']

# %%
print(X)
print()
# Out:
#                        Index        pH   Nitrate  Turbidity  Fluoride  \
# Datetime
# 2023-11-26 16:00:00        1  6.917863  3.734167   0.019007  0.622874
# 2023-01-31 08:00:00        2  5.443762  3.816994   0.319956  0.423423
# 2023-06-29 07:00:00        4  8.091909  9.925788   0.004867  0.222912
# 2023-04-11 04:00:00        7  7.258203  9.261676   0.047803  1.016196
# 2023-04-07 12:00:00        9  7.100650  3.620641   0.050613  0.842107
# ...                      ...       ...       ...        ...       ...
# 2023-12-30 15:00:00  1048569  6.957090  2.256611   0.159260  1.874301
# 2023-03-15 14:00:00  1048570  8.186428  5.968850   0.020610  1.194165
# 2023-12-16 00:00:00  1048571  8.046225  3.678714   0.878835  1.203689
# 2023-06-18 16:00:00  1048572  7.443582  7.893399   0.701053  0.115412
# 2023-05-05 03:00:00  1048573  6.897232  5.757980   0.156424  0.554729
#
#                      Chlorine  Total Dissolved Solids  Water Temperature  \
# Datetime
# 2023-11-26 16:00:00  3.292038              284.641984          15.348981
# 2023-01-31 08:00:00  3.560224              570.054094          11.643467
# 2023-06-29 07:00:00  3.177849              168.075545          15.249416
# 2023-04-11 04:00:00  2.325094              214.553104          15.891905
# 2023-04-07 12:00:00  2.284971              113.909077          11.899376
# ...                       ...                     ...                ...
# 2023-12-30 15:00:00  3.384594              155.306913          17.146633
# 2023-03-15 14:00:00  2.718928              220.571485           5.491908
# 2023-12-16 00:00:00  2.312058              406.095969          10.143768
# 2023-06-18 16:00:00  3.410297              439.086461          14.612881
# 2023-05-05 03:00:00  2.803234              278.051032           7.351956
#
#                      Air Temperature
# Datetime
# 2023-11-26 16:00:00        71.220586
# 2023-01-31 08:00:00        44.891330
# 2023-06-29 07:00:00        69.336671
# 2023-04-11 04:00:00        61.139140
# 2023-04-07 12:00:00        14.010268
# ...                              ...
# 2023-12-30 15:00:00        64.890571
# 2023-03-15 14:00:00        43.817452
# 2023-12-16 00:00:00        34.626853
# 2023-06-18 16:00:00        55.460415
# 2023-05-05 03:00:00        65.055864
#
# [701056 rows x 9 columns]

# %%
print(Y)
# Out:
# Datetime
# 2023-11-26 16:00:00    0
# 2023-01-31 08:00:00    0
# 2023-06-29 07:00:00    0
# 2023-04-11 04:00:00    0
# 2023-04-07 12:00:00    0
#                       ..
# 2023-12-30 15:00:00    0
# 2023-03-15 14:00:00    0
# 2023-12-16 00:00:00    0
# 2023-06-18 16:00:00    0
# 2023-05-05 03:00:00    0
# Name: Target, Length: 701056, dtype: int64

# %% [markdown]
# **Training and Testing Data**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, stratify = Y, random_state = 1)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (701056, 9) (630950, 9) (70106, 9)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Model Training using Logistic Regression**

# %%
model = LogisticRegression()

# %%
# training the logistic regression model by using training data
model.fit(X_train, Y_train)
LogisticRegression()
# Out:
# LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 0)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
print('Accuracy of logistic regression classifier on training set: {:2f}'
            .format(logreg.score(X_train, Y_train)))
# Out:
# Accuracy of logistic regression classifier on training set: 0.788270

# %%
print('Accuracy of logistic regression classifier on testing set: {:2f}'
            .format(logreg.score(X_test, Y_test)))
# Out:
# Accuracy of logistic regression classifier on testing set: 0.789597

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(X_train, Y_train)
print('Accuracy of Decision Tree Classifier on training set: {:2f}'
            .format(clf.score(X_train, Y_train)))
print('Accuracy of Decision Tree Classifier on testing set: {:2f}'
            .format(clf.score(X_test, Y_test)))
# Out:
# Accuracy of Decision Tree Classifier on training set: 1.000000
# Accuracy of Decision Tree Classifier on testing set: 0.999994

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, Y_train)
print('Accuracy of GNB Classifier on training set: {:2f}'
            .format(gnb.score(X_train, Y_train)))
print('Accuracy of GNB Classifier on testing set: {:2f}'
            .format(gnb.score(X_test, Y_test)))
# Out:
# Accuracy of GNB Classifier on training set: 0.818590
# Accuracy of GNB Classifier on testing set: 0.820203

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
model = RandomForestClassifier(n_estimators = 100, random_state = 0)

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# accuracy on training data
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction, Y_train)
print('accuracy on training data:', training_data_accuracy)
# Out:
# accuracy on training data: 1.0

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('accuracy on testing data:', testing_data_accuracy)
# Out:
# accuracy on testing data: 0.99983453532956

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, Y_train)
print('Accuracy of SVM Classifier on training set: {:2f}'
            .format(svm.score(X_train, Y_train)))
print('Accuracy of SVM Classifier on testing set: {:2f}'
            .format(svm.score(X_test, Y_test)))
